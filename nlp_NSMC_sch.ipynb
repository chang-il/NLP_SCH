# %% [markdown]
# <a href="https://colab.research.google.com/github/chang-il/NLP_SCH/blob/main/nlp_NSMC_sch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install torch
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/50/0c/7d5950fcd80b029be0a8891727ba21e0cd27692c407c51261c3c921f6da3/transformers-4.1.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 8.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 17.1MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 41.9MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=6f12a04369d4e9c149e1ef22b853174cf34a7bdfdf4eb107bc311c9b7234e266
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.1.1
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.7.0+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.19.4)

# %%
import tensorflow as tf
import torch

from transformers import ElectraTokenizer
from transformers import ElectraForSequenceClassification, AdamW
from transformers import get_linear_schedule_with_warmup
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import random
import time
import datetime

# %% [markdown]
# # **데이터로드**

# %%
# 네이버 영화리뷰 감정분석 데이터 다운로드
# !git clone https://github.com/e9t/nsmc.git
# Out:
# Cloning into 'nsmc'...
# remote: Enumerating objects: 14763, done.
# remote: Total 14763 (delta 0), reused 0 (delta 0), pack-reused 14763
# Receiving objects: 100% (14763/14763), 56.19 MiB | 23.54 MiB/s, done.
# Resolving deltas: 100% (1749/1749), done.
# Checking out files: 100% (14737/14737), done.

# %%
# train/test set 데이터 로드

train = pd.read_csv("nsmc/ratings_train.txt", sep='\t')
test = pd.read_csv("nsmc/ratings_test.txt", sep='\t')

print(train.shape)
print(test.shape)
# Out:
# (150000, 3)
# (50000, 3)

# %%
train.head()
test.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %% [markdown]
# # **전처리**

# %%
MAX_LEN = 128

def getInputs(dataset):
  data = dataset.copy(deep=True)

  if 'document' in data.columns:
    sentences = data['document']
  else:
    sentences = data['Sentence']

  sentences = ["[CLS] " + str(sentence) + " [SEP]" for sentence in sentences]
  
  tokenizer = ElectraTokenizer.from_pretrained("monologg/koelectra-base-v2-discriminator", do_lower_case=False)
  tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]

  input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]
  input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

  attention_masks = []
  for seq in input_ids:
      seq_mask = [float(i>0) for i in seq]
      attention_masks.append(seq_mask)

  return input_ids, attention_masks

# %%
def getIndex(dataset):
  data = dataset.copy(deep = True)
  input_index = data.index.tolist()
  return torch.tensor(input_index)

# %%
labels = train['label'].values
ratings_inputs, ratings_masks = getInputs(train)
test_inputs, test_masks = getInputs(test)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=255190.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=65.0, style=ProgressStyle(description_w…

# %%
# 훈련셋과 검증셋으로 분리
train_inputs, validation_inputs, train_labels, validation_labels = train_test_split(ratings_inputs, labels, random_state=2018, test_size=0.1)

# 어텐션 마스크를 훈련셋과 검증셋으로 분리
train_masks, validation_masks, _, _ = train_test_split(ratings_masks, ratings_inputs, random_state=2018, test_size=0.1)

# %%
# 데이터를 파이토치의 텐서로 변환
train_inputs = torch.tensor(train_inputs)
train_labels = torch.tensor(train_labels)
train_masks = torch.tensor(train_masks)

validation_inputs = torch.tensor(validation_inputs)
validation_labels = torch.tensor(validation_labels)
validation_masks = torch.tensor(validation_masks)			

test_index = getIndex(test)
test_inputs = torch.tensor(test_inputs)
test_masks = torch.tensor(test_masks)

# %%
# 배치 사이즈
batch_size = 32

# 파이토치의 DataLoader로 입력, 마스크, 라벨을 묶어 데이터 설정
# 학습시 배치 사이즈 만큼 데이터를 가져옴
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

validation_data = TensorDataset(validation_inputs, validation_masks, validation_labels)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

test_data = TensorDataset(test_index, test_inputs, test_masks)
test_sampler = RandomSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# # **모델 학습**

# %%
if torch.cuda.is_available():    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print('No GPU available, using the CPU instead.')
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
# ELECTRA 모델 생성

model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v2-discriminator", num_labels = 2)
model.cuda()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=487.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=443133604.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at monologg/koelectra-base-v2-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v2-discriminator and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(32200, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
# 옵티마이저 설정
optimizer = AdamW(model.parameters(),
                  lr = 3e-5, # 학습률
                  eps = 1e-8 # 0으로 나누는 것을 방지하기 위한 epsilon 값
                )

# 에폭수
epochs = 4

# 총 훈련 스텝 : 배치반복 횟수 * 에폭
total_steps = len(train_dataloader) * epochs

# 학습률을 조금씩 감소시키는 스케줄러 생성
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)

# %%
# 정확도 계산 함수
def flat_accuracy(preds, labels):
    
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
# 시간 표시 함수
def format_time(elapsed):

    # 반올림
    elapsed_rounded = int(round((elapsed)))
    
    # hh:mm:ss으로 형태 변경
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
# 재현을 위해 랜덤시드 고정
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# 그래디언트 초기화
model.zero_grad()

# 에폭만큼 반복
for epoch_i in range(0, epochs):
    
    # ========================================
    #               Training
    # ========================================
    
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # 시작 시간 설정
    t0 = time.time()

    # 로스 초기화
    total_loss = 0

    # 훈련모드로 변경
    model.train()
        
    # 데이터로더에서 배치만큼 반복하여 가져옴
    for step, batch in enumerate(train_dataloader):
        # 경과 정보 표시
        if step % 500 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # 배치를 GPU에 넣음
        batch = tuple(t.to(device) for t in batch)
        
        # 배치에서 데이터 추출
        b_input_ids, b_input_mask, b_labels = batch

        # Forward 수행                
        outputs = model(b_input_ids, 
                        token_type_ids=None, 
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # 로스 구함
        loss = outputs[0]

        # 총 로스 계산
        total_loss += loss.item()

        # Backward 수행으로 그래디언트 계산
        loss.backward()

        # 그래디언트 클리핑
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # 그래디언트를 통해 가중치 파라미터 업데이트
        optimizer.step()

        # 스케줄러로 학습률 감소
        scheduler.step()

        # 그래디언트 초기화
        model.zero_grad()

    # 평균 로스 계산
    avg_train_loss = total_loss / len(train_dataloader)            

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(format_time(time.time() - t0)))
        
    # ========================================
    #               Validation
    # ========================================

    print("")
    print("Running Validation...")

    #시작 시간 설정
    t0 = time.time()

    # 평가모드로 변경
    model.eval()

    # 변수 초기화
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # 데이터로더에서 배치만큼 반복하여 가져옴
    for batch in validation_dataloader:
        # 배치를 GPU에 넣음
        batch = tuple(t.to(device) for t in batch)
        
        # 배치에서 데이터 추출
        b_input_ids, b_input_mask, b_labels = batch
        
        # 그래디언트 계산 안함
        with torch.no_grad():     
            # Forward 수행
            outputs = model(b_input_ids, 
                            token_type_ids=None, 
                            attention_mask=b_input_mask)
        
        # 로스 구함
        logits = outputs[0]

        # CPU로 데이터 이동
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # 출력 로직과 라벨을 비교하여 정확도 계산
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        eval_accuracy += tmp_eval_accuracy
        nb_eval_steps += 1

    print("  Accuracy: {0:.2f}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch   500  of  4,219.    Elapsed: 0:05:35.
#   Batch 1,000  of  4,219.    Elapsed: 0:11:23.
#   Batch 1,500  of  4,219.    Elapsed: 0:17:11.
#   Batch 2,000  of  4,219.    Elapsed: 0:22:58.
#   Batch 2,500  of  4,219.    Elapsed: 0:28:46.
#   Batch 3,000  of  4,219.    Elapsed: 0:34:33.
#   Batch 3,500  of  4,219.    Elapsed: 0:40:20.
#   Batch 4,000  of  4,219.    Elapsed: 0:46:08.
#
#   Average training loss: 0.30
#   Training epcoh took: 0:48:40
#
# Running Validation...
#   Accuracy: 0.90
#   Validation took: 0:01:57
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch   500  of  4,219.    Elapsed: 0:05:47.
#   Batch 1,000  of  4,219.    Elapsed: 0:11:35.
#   Batch 1,500  of  4,219.    Elapsed: 0:17:22.
#   Batch 2,000  of  4,219.    Elapsed: 0:23:09.
#   Batch 2,500  of  4,219.    Elapsed: 0:28:57.
#   Batch 3,000  of  4,219.    Elapsed: 0:34:44.
#   Batch 3,500  of  4,219.    Elapsed: 0:40:32.
#   Batch 4,000  of  4,219.    Elapsed: 0:46:19.
#
#   Average training loss: 0.21
#   Training epcoh took: 0:48:51
#
# Running Validation...
#   Accuracy: 0.90
#   Validation took: 0:01:57
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch   500  of  4,219.    Elapsed: 0:05:48.
#   Batch 1,000  of  4,219.    Elapsed: 0:11:35.
#   Batch 1,500  of  4,219.    Elapsed: 0:17:22.
#   Batch 2,000  of  4,219.    Elapsed: 0:23:10.
#   Batch 2,500  of  4,219.    Elapsed: 0:28:57.
#   Batch 3,000  of  4,219.    Elapsed: 0:34:44.
#   Batch 3,500  of  4,219.    Elapsed: 0:40:31.
#   Batch 4,000  of  4,219.    Elapsed: 0:46:19.
#
#   Average training loss: 0.14
#   Training epcoh took: 0:48:51
#
# Running Validation...
#   Accuracy: 0.90
#   Validation took: 0:01:56
#
# ======== Epoch 4 / 4 ========
# Training...
#   Batch   500  of  4,219.    Elapsed: 0:05:46.
#   Batch 1,000  of  4,219.    Elapsed: 0:11:33.
#   Batch 1,500  of  4,219.    Elapsed: 0:17:20.
#   Batch 2,000  of  4,219.    Elapsed: 0:23:06.
#   Batch 2,500  of  4,219.    Elapsed: 0:28:53.
#   Batch 3,000  of  4,219.    Elapsed: 0:34:39.
#   Batch 3,500  of  4,219.    Elapsed: 0:40:26.
#   Batch 4,000  of  4,219.    Elapsed: 0:46:12.
#
#   Average training loss: 0.10
#   Training epcoh took: 0:48:43
#
# Running Validation...
#   Accuracy: 0.90
#   Validation took: 0:01:57
#
# Training complete!

# %% [markdown]
# # **테스트셋 평가**

# %%
tmp_test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=1)
test_result = test.copy(deep = True)
test_result['Predicted'] = 'default'
classes = [0, 1]

#시작 시간 설정
t0 = time.time()

# 평가모드로 변경
model.eval()

# 변수 초기화
nb_eval_steps, nb_eval_examples = 0, 0

# 데이터로더에서 배치만큼 반복하여 가져옴
for step, batch in enumerate(tmp_test_dataloader):
    # 경과 정보 표시
    if step % 100 == 0 and not step == 0:
        elapsed = format_time(time.time() - t0)
        print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(test_dataloader), elapsed))

    # 배치를 GPU에 넣음
    batch = tuple(t.to(device) for t in batch)
    
    # 배치에서 데이터 추출
    b_index, b_input_ids, b_input_mask = batch
    
    # 그래디언트 계산 안함
    with torch.no_grad():     
        # Forward 수행
        outputs = model(b_input_ids, 
                        token_type_ids=None, 
                        attention_mask=b_input_mask)
    
    # 로스 구함
    logits = outputs[0]

    # CPU로 데이터 이동
    logits = logits.detach().cpu().numpy()
    idx = b_index.item()
    test_result['Predicted'][idx] = classes[np.argmax(logits)]
    

    nb_eval_steps += 1

print("")
print("Test took: {:}".format(format_time(time.time() - t0)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Batch   100  of  1,563.    Elapsed: 0:00:01.
#   Batch   200  of  1,563.    Elapsed: 0:00:02.
#   Batch   300  of  1,563.    Elapsed: 0:00:04.
#   Batch   400  of  1,563.    Elapsed: 0:00:05.
#   Batch   500  of  1,563.    Elapsed: 0:00:06.
#   Batch   600  of  1,563.    Elapsed: 0:00:07.
#   Batch   700  of  1,563.    Elapsed: 0:00:08.
#   Batch   800  of  1,563.    Elapsed: 0:00:10.
#   Batch   900  of  1,563.    Elapsed: 0:00:11.
#   Batch 1,000  of  1,563.    Elapsed: 0:00:12.
#   Batch 1,100  of  1,563.    Elapsed: 0:00:13.
#   Batch 1,200  of  1,563.    Elapsed: 0:00:14.
#   Batch 1,300  of  1,563.    Elapsed: 0:00:16.
#   Batch 1,400  of  1,563.    Elapsed: 0:00:17.
#   Batch 1,500  of  1,563.    Elapsed: 0:00:18.
#   Batch 1,600  of  1,563.    Elapsed: 0:00:19.
#   Batch 1,700  of  1,563.    Elapsed: 0:00:20.
#   Batch 1,800  of  1,563.    Elapsed: 0:00:22.
#   Batch 1,900  of  1,563.    Elapsed: 0:00:23.
#   Batch 2,000  of  1,563.    Elapsed: 0:00:24.
#   Batch 2,100  of  1,563.    Elapsed: 0:00:26.
#   Batch 2,200  of  1,563.    Elapsed: 0:00:27.
#   Batch 2,300  of  1,563.    Elapsed: 0:00:28.
#   Batch 2,400  of  1,563.    Elapsed: 0:00:29.
#   Batch 2,500  of  1,563.    Elapsed: 0:00:31.
#   Batch 2,600  of  1,563.    Elapsed: 0:00:32.
#   Batch 2,700  of  1,563.    Elapsed: 0:00:33.
#   Batch 2,800  of  1,563.    Elapsed: 0:00:34.
#   Batch 2,900  of  1,563.    Elapsed: 0:00:35.
#   Batch 3,000  of  1,563.    Elapsed: 0:00:37.
#   Batch 3,100  of  1,563.    Elapsed: 0:00:38.
#   Batch 3,200  of  1,563.    Elapsed: 0:00:39.
#   Batch 3,300  of  1,563.    Elapsed: 0:00:40.
#   Batch 3,400  of  1,563.    Elapsed: 0:00:42.
#   Batch 3,500  of  1,563.    Elapsed: 0:00:43.
#   Batch 3,600  of  1,563.    Elapsed: 0:00:44.
#   Batch 3,700  of  1,563.    Elapsed: 0:00:45.
#   Batch 3,800  of  1,563.    Elapsed: 0:00:47.
#   Batch 3,900  of  1,563.    Elapsed: 0:00:48.
#   Batch 4,000  of  1,563.    Elapsed: 0:00:49.
#   Batch 4,100  of  1,563.    Elapsed: 0:00:50.
#   Batch 4,200  of  1,563.    Elapsed: 0:00:52.
#   Batch 4,300  of  1,563.    Elapsed: 0:00:53.
#   Batch 4,400  of  1,563.    Elapsed: 0:00:54.
#   Batch 4,500  of  1,563.    Elapsed: 0:00:55.
#   Batch 4,600  of  1,563.    Elapsed: 0:00:57.
#   Batch 4,700  of  1,563.    Elapsed: 0:00:58.
#   Batch 4,800  of  1,563.    Elapsed: 0:00:59.
#   Batch 4,900  of  1,563.    Elapsed: 0:01:00.
#   Batch 5,000  of  1,563.    Elapsed: 0:01:01.
#   Batch 5,100  of  1,563.    Elapsed: 0:01:02.
#   Batch 5,200  of  1,563.    Elapsed: 0:01:04.
#   Batch 5,300  of  1,563.    Elapsed: 0:01:05.
#   Batch 5,400  of  1,563.    Elapsed: 0:01:06.
#   Batch 5,500  of  1,563.    Elapsed: 0:01:07.
#   Batch 5,600  of  1,563.    Elapsed: 0:01:08.
#   Batch 5,700  of  1,563.    Elapsed: 0:01:10.
#   Batch 5,800  of  1,563.    Elapsed: 0:01:11.
#   Batch 5,900  of  1,563.    Elapsed: 0:01:12.
#   Batch 6,000  of  1,563.    Elapsed: 0:01:13.
#   Batch 6,100  of  1,563.    Elapsed: 0:01:15.
#   Batch 6,200  of  1,563.    Elapsed: 0:01:16.
#   Batch 6,300  of  1,563.    Elapsed: 0:01:17.
#   Batch 6,400  of  1,563.    Elapsed: 0:01:18.
#   Batch 6,500  of  1,563.    Elapsed: 0:01:20.
#   Batch 6,600  of  1,563.    Elapsed: 0:01:21.
#   Batch 6,700  of  1,563.    Elapsed: 0:01:22.
#   Batch 6,800  of  1,563.    Elapsed: 0:01:23.
#   Batch 6,900  of  1,563.    Elapsed: 0:01:24.
#   Batch 7,000  of  1,563.    Elapsed: 0:01:26.
#   Batch 7,100  of  1,563.    Elapsed: 0:01:27.
#   Batch 7,200  of  1,563.    Elapsed: 0:01:28.
#   Batch 7,300  of  1,563.    Elapsed: 0:01:29.
#   Batch 7,400  of  1,563.    Elapsed: 0:01:30.
#   Batch 7,500  of  1,563.    Elapsed: 0:01:32.
#   Batch 7,600  of  1,563.    Elapsed: 0:01:33.
#   Batch 7,700  of  1,563.    Elapsed: 0:01:34.
#   Batch 7,800  of  1,563.    Elapsed: 0:01:35.
#   Batch 7,900  of  1,563.    Elapsed: 0:01:36.
#   Batch 8,000  of  1,563.    Elapsed: 0:01:38.
#   Batch 8,100  of  1,563.    Elapsed: 0:01:39.
#   Batch 8,200  of  1,563.    Elapsed: 0:01:40.
#   Batch 8,300  of  1,563.    Elapsed: 0:01:41.
#   Batch 8,400  of  1,563.    Elapsed: 0:01:42.
#   Batch 8,500  of  1,563.    Elapsed: 0:01:43.
#   Batch 8,600  of  1,563.    Elapsed: 0:01:45.
#   Batch 8,700  of  1,563.    Elapsed: 0:01:46.
#   Batch 8,800  of  1,563.    Elapsed: 0:01:47.
#   Batch 8,900  of  1,563.    Elapsed: 0:01:48.
#   Batch 9,000  of  1,563.    Elapsed: 0:01:50.
#   Batch 9,100  of  1,563.    Elapsed: 0:01:51.
#   Batch 9,200  of  1,563.    Elapsed: 0:01:52.
#   Batch 9,300  of  1,563.    Elapsed: 0:01:53.
#   Batch 9,400  of  1,563.    Elapsed: 0:01:55.
#   Batch 9,500  of  1,563.    Elapsed: 0:01:56.
#   Batch 9,600  of  1,563.    Elapsed: 0:01:57.
#   Batch 9,700  of  1,563.    Elapsed: 0:01:58.
#   Batch 9,800  of  1,563.    Elapsed: 0:01:59.
#   Batch 9,900  of  1,563.    Elapsed: 0:02:01.
#   Batch 10,000  of  1,563.    Elapsed: 0:02:02.
#   Batch 10,100  of  1,563.    Elapsed: 0:02:03.
#   Batch 10,200  of  1,563.    Elapsed: 0:02:04.
#   Batch 10,300  of  1,563.    Elapsed: 0:02:05.
#   Batch 10,400  of  1,563.    Elapsed: 0:02:07.
#   Batch 10,500  of  1,563.    Elapsed: 0:02:08.
#   Batch 10,600  of  1,563.    Elapsed: 0:02:09.
#   Batch 10,700  of  1,563.    Elapsed: 0:02:10.
#   Batch 10,800  of  1,563.    Elapsed: 0:02:12.
#   Batch 10,900  of  1,563.    Elapsed: 0:02:13.
#   Batch 11,000  of  1,563.    Elapsed: 0:02:14.
#   Batch 11,100  of  1,563.    Elapsed: 0:02:15.
#   Batch 11,200  of  1,563.    Elapsed: 0:02:16.
#   Batch 11,300  of  1,563.    Elapsed: 0:02:17.
#   Batch 11,400  of  1,563.    Elapsed: 0:02:19.
#   Batch 11,500  of  1,563.    Elapsed: 0:02:20.
#   Batch 11,600  of  1,563.    Elapsed: 0:02:21.
#   Batch 11,700  of  1,563.    Elapsed: 0:02:22.
#   Batch 11,800  of  1,563.    Elapsed: 0:02:23.
#   Batch 11,900  of  1,563.    Elapsed: 0:02:24.
#   Batch 12,000  of  1,563.    Elapsed: 0:02:26.
#   Batch 12,100  of  1,563.    Elapsed: 0:02:27.
#   Batch 12,200  of  1,563.    Elapsed: 0:02:28.
#   Batch 12,300  of  1,563.    Elapsed: 0:02:29.
#   Batch 12,400  of  1,563.    Elapsed: 0:02:30.
#   Batch 12,500  of  1,563.    Elapsed: 0:02:32.
#   Batch 12,600  of  1,563.    Elapsed: 0:02:33.
#   Batch 12,700  of  1,563.    Elapsed: 0:02:34.
#   Batch 12,800  of  1,563.    Elapsed: 0:02:35.
#   Batch 12,900  of  1,563.    Elapsed: 0:02:36.
#   Batch 13,000  of  1,563.    Elapsed: 0:02:38.
#   Batch 13,100  of  1,563.    Elapsed: 0:02:39.
#   Batch 13,200  of  1,563.    Elapsed: 0:02:40.
#   Batch 13,300  of  1,563.    Elapsed: 0:02:41.
#   Batch 13,400  of  1,563.    Elapsed: 0:02:42.
#   Batch 13,500  of  1,563.    Elapsed: 0:02:44.
#   Batch 13,600  of  1,563.    Elapsed: 0:02:45.
#   Batch 13,700  of  1,563.    Elapsed: 0:02:46.
#   Batch 13,800  of  1,563.    Elapsed: 0:02:47.
#   Batch 13,900  of  1,563.    Elapsed: 0:02:48.
#   Batch 14,000  of  1,563.    Elapsed: 0:02:49.
#   Batch 14,100  of  1,563.    Elapsed: 0:02:51.
#   Batch 14,200  of  1,563.    Elapsed: 0:02:52.
#   Batch 14,300  of  1,563.    Elapsed: 0:02:53.
#   Batch 14,400  of  1,563.    Elapsed: 0:02:54.
#   Batch 14,500  of  1,563.    Elapsed: 0:02:55.
#   Batch 14,600  of  1,563.    Elapsed: 0:02:57.
#   Batch 14,700  of  1,563.    Elapsed: 0:02:58.
#   Batch 14,800  of  1,563.    Elapsed: 0:02:59.
#   Batch 14,900  of  1,563.    Elapsed: 0:03:00.
#   Batch 15,000  of  1,563.    Elapsed: 0:03:01.
#   Batch 15,100  of  1,563.    Elapsed: 0:03:03.
#   Batch 15,200  of  1,563.    Elapsed: 0:03:04.
#   Batch 15,300  of  1,563.    Elapsed: 0:03:05.
#   Batch 15,400  of  1,563.    Elapsed: 0:03:06.
#   Batch 15,500  of  1,563.    Elapsed: 0:03:07.
#   Batch 15,600  of  1,563.    Elapsed: 0:03:08.
#   Batch 15,700  of  1,563.    Elapsed: 0:03:10.
#   Batch 15,800  of  1,563.    Elapsed: 0:03:11.
#   Batch 15,900  of  1,563.    Elapsed: 0:03:12.
#   Batch 16,000  of  1,563.    Elapsed: 0:03:13.
#   Batch 16,100  of  1,563.    Elapsed: 0:03:15.
#   Batch 16,200  of  1,563.    Elapsed: 0:03:16.
#   Batch 16,300  of  1,563.    Elapsed: 0:03:17.
#   Batch 16,400  of  1,563.    Elapsed: 0:03:18.
#   Batch 16,500  of  1,563.    Elapsed: 0:03:19.
#   Batch 16,600  of  1,563.    Elapsed: 0:03:21.
#   Batch 16,700  of  1,563.    Elapsed: 0:03:22.
#   Batch 16,800  of  1,563.    Elapsed: 0:03:23.
#   Batch 16,900  of  1,563.    Elapsed: 0:03:24.
#   Batch 17,000  of  1,563.    Elapsed: 0:03:26.
#   Batch 17,100  of  1,563.    Elapsed: 0:03:27.
#   Batch 17,200  of  1,563.    Elapsed: 0:03:28.
#   Batch 17,300  of  1,563.    Elapsed: 0:03:29.
#   Batch 17,400  of  1,563.    Elapsed: 0:03:30.
#   Batch 17,500  of  1,563.    Elapsed: 0:03:32.
#   Batch 17,600  of  1,563.    Elapsed: 0:03:33.
#   Batch 17,700  of  1,563.    Elapsed: 0:03:34.
#   Batch 17,800  of  1,563.    Elapsed: 0:03:35.
#   Batch 17,900  of  1,563.    Elapsed: 0:03:36.
#   Batch 18,000  of  1,563.    Elapsed: 0:03:38.
#   Batch 18,100  of  1,563.    Elapsed: 0:03:39.
#   Batch 18,200  of  1,563.    Elapsed: 0:03:40.
#   Batch 18,300  of  1,563.    Elapsed: 0:03:41.
#   Batch 18,400  of  1,563.    Elapsed: 0:03:42.
#   Batch 18,500  of  1,563.    Elapsed: 0:03:43.
#   Batch 18,600  of  1,563.    Elapsed: 0:03:45.
#   Batch 18,700  of  1,563.    Elapsed: 0:03:46.
#   Batch 18,800  of  1,563.    Elapsed: 0:03:47.
#   Batch 18,900  of  1,563.    Elapsed: 0:03:48.
#   Batch 19,000  of  1,563.    Elapsed: 0:03:50.
#   Batch 19,100  of  1,563.    Elapsed: 0:03:51.
#   Batch 19,200  of  1,563.    Elapsed: 0:03:52.
#   Batch 19,300  of  1,563.    Elapsed: 0:03:53.
#   Batch 19,400  of  1,563.    Elapsed: 0:03:54.
#   Batch 19,500  of  1,563.    Elapsed: 0:03:55.
#   Batch 19,600  of  1,563.    Elapsed: 0:03:57.
#   Batch 19,700  of  1,563.    Elapsed: 0:03:58.
#   Batch 19,800  of  1,563.    Elapsed: 0:03:59.
#   Batch 19,900  of  1,563.    Elapsed: 0:04:00.
#   Batch 20,000  of  1,563.    Elapsed: 0:04:02.
#   Batch 20,100  of  1,563.    Elapsed: 0:04:03.
#   Batch 20,200  of  1,563.    Elapsed: 0:04:04.
#   Batch 20,300  of  1,563.    Elapsed: 0:04:05.
#   Batch 20,400  of  1,563.    Elapsed: 0:04:06.
#   Batch 20,500  of  1,563.    Elapsed: 0:04:07.
#   Batch 20,600  of  1,563.    Elapsed: 0:04:09.
#   Batch 20,700  of  1,563.    Elapsed: 0:04:10.
#   Batch 20,800  of  1,563.    Elapsed: 0:04:11.
#   Batch 20,900  of  1,563.    Elapsed: 0:04:12.
#   Batch 21,000  of  1,563.    Elapsed: 0:04:13.
#   Batch 21,100  of  1,563.    Elapsed: 0:04:15.
#   Batch 21,200  of  1,563.    Elapsed: 0:04:16.
#   Batch 21,300  of  1,563.    Elapsed: 0:04:17.
#   Batch 21,400  of  1,563.    Elapsed: 0:04:18.
#   Batch 21,500  of  1,563.    Elapsed: 0:04:19.
#   Batch 21,600  of  1,563.    Elapsed: 0:04:20.
#   Batch 21,700  of  1,563.    Elapsed: 0:04:22.
#   Batch 21,800  of  1,563.    Elapsed: 0:04:23.
#   Batch 21,900  of  1,563.    Elapsed: 0:04:24.
#   Batch 22,000  of  1,563.    Elapsed: 0:04:26.
#   Batch 22,100  of  1,563.    Elapsed: 0:04:27.
#   Batch 22,200  of  1,563.    Elapsed: 0:04:28.
#   Batch 22,300  of  1,563.    Elapsed: 0:04:29.
#   Batch 22,400  of  1,563.    Elapsed: 0:04:30.
#   Batch 22,500  of  1,563.    Elapsed: 0:04:32.
#   Batch 22,600  of  1,563.    Elapsed: 0:04:33.
#   Batch 22,700  of  1,563.    Elapsed: 0:04:34.
#   Batch 22,800  of  1,563.    Elapsed: 0:04:35.
#   Batch 22,900  of  1,563.    Elapsed: 0:04:36.
#   Batch 23,000  of  1,563.    Elapsed: 0:04:37.
#   Batch 23,100  of  1,563.    Elapsed: 0:04:39.
#   Batch 23,200  of  1,563.    Elapsed: 0:04:40.
#   Batch 23,300  of  1,563.    Elapsed: 0:04:41.
#   Batch 23,400  of  1,563.    Elapsed: 0:04:42.
#   Batch 23,500  of  1,563.    Elapsed: 0:04:44.
#   Batch 23,600  of  1,563.    Elapsed: 0:04:45.
#   Batch 23,700  of  1,563.    Elapsed: 0:04:46.
#   Batch 23,800  of  1,563.    Elapsed: 0:04:47.
#   Batch 23,900  of  1,563.    Elapsed: 0:04:49.
#   Batch 24,000  of  1,563.    Elapsed: 0:04:50.
#   Batch 24,100  of  1,563.    Elapsed: 0:04:51.
#   Batch 24,200  of  1,563.    Elapsed: 0:04:52.
#   Batch 24,300  of  1,563.    Elapsed: 0:04:53.
#   Batch 24,400  of  1,563.    Elapsed: 0:04:54.
#   Batch 24,500  of  1,563.    Elapsed: 0:04:56.
#   Batch 24,600  of  1,563.    Elapsed: 0:04:57.
#   Batch 24,700  of  1,563.    Elapsed: 0:04:58.
#   Batch 24,800  of  1,563.    Elapsed: 0:04:59.
#   Batch 24,900  of  1,563.    Elapsed: 0:05:00.
#   Batch 25,000  of  1,563.    Elapsed: 0:05:02.
#   Batch 25,100  of  1,563.    Elapsed: 0:05:03.
#   Batch 25,200  of  1,563.    Elapsed: 0:05:04.
#   Batch 25,300  of  1,563.    Elapsed: 0:05:05.
#   Batch 25,400  of  1,563.    Elapsed: 0:05:07.
#   Batch 25,500  of  1,563.    Elapsed: 0:05:08.
#   Batch 25,600  of  1,563.    Elapsed: 0:05:09.
#   Batch 25,700  of  1,563.    Elapsed: 0:05:10.
#   Batch 25,800  of  1,563.    Elapsed: 0:05:12.
#   Batch 25,900  of  1,563.    Elapsed: 0:05:13.
#   Batch 26,000  of  1,563.    Elapsed: 0:05:14.
#   Batch 26,100  of  1,563.    Elapsed: 0:05:15.
#   Batch 26,200  of  1,563.    Elapsed: 0:05:16.
#   Batch 26,300  of  1,563.    Elapsed: 0:05:18.
#   Batch 26,400  of  1,563.    Elapsed: 0:05:19.
#   Batch 26,500  of  1,563.    Elapsed: 0:05:20.
#   Batch 26,600  of  1,563.    Elapsed: 0:05:21.
#   Batch 26,700  of  1,563.    Elapsed: 0:05:22.
#   Batch 26,800  of  1,563.    Elapsed: 0:05:24.
#   Batch 26,900  of  1,563.    Elapsed: 0:05:25.
#   Batch 27,000  of  1,563.    Elapsed: 0:05:26.
#   Batch 27,100  of  1,563.    Elapsed: 0:05:27.
#   Batch 27,200  of  1,563.    Elapsed: 0:05:28.
#   Batch 27,300  of  1,563.    Elapsed: 0:05:29.
#   Batch 27,400  of  1,563.    Elapsed: 0:05:31.
#   Batch 27,500  of  1,563.    Elapsed: 0:05:32.
#   Batch 27,600  of  1,563.    Elapsed: 0:05:33.
#   Batch 27,700  of  1,563.    Elapsed: 0:05:34.
#   Batch 27,800  of  1,563.    Elapsed: 0:05:35.
#   Batch 27,900  of  1,563.    Elapsed: 0:05:36.
#   Batch 28,000  of  1,563.    Elapsed: 0:05:38.
#   Batch 28,100  of  1,563.    Elapsed: 0:05:39.
#   Batch 28,200  of  1,563.    Elapsed: 0:05:40.
#   Batch 28,300  of  1,563.    Elapsed: 0:05:41.
#   Batch 28,400  of  1,563.    Elapsed: 0:05:42.
#   Batch 28,500  of  1,563.    Elapsed: 0:05:44.
#   Batch 28,600  of  1,563.    Elapsed: 0:05:45.
#   Batch 28,700  of  1,563.    Elapsed: 0:05:46.
#   Batch 28,800  of  1,563.    Elapsed: 0:05:48.
#   Batch 28,900  of  1,563.    Elapsed: 0:05:49.
#   Batch 29,000  of  1,563.    Elapsed: 0:05:50.
#   Batch 29,100  of  1,563.    Elapsed: 0:05:51.
#   Batch 29,200  of  1,563.    Elapsed: 0:05:52.
#   Batch 29,300  of  1,563.    Elapsed: 0:05:53.
#   Batch 29,400  of  1,563.    Elapsed: 0:05:55.
#   Batch 29,500  of  1,563.    Elapsed: 0:05:56.
#   Batch 29,600  of  1,563.    Elapsed: 0:05:57.
#   Batch 29,700  of  1,563.    Elapsed: 0:05:58.
#   Batch 29,800  of  1,563.    Elapsed: 0:05:59.
#   Batch 29,900  of  1,563.    Elapsed: 0:06:00.
#   Batch 30,000  of  1,563.    Elapsed: 0:06:02.
#   Batch 30,100  of  1,563.    Elapsed: 0:06:03.
#   Batch 30,200  of  1,563.    Elapsed: 0:06:04.
#   Batch 30,300  of  1,563.    Elapsed: 0:06:05.
#   Batch 30,400  of  1,563.    Elapsed: 0:06:07.
#   Batch 30,500  of  1,563.    Elapsed: 0:06:08.
#   Batch 30,600  of  1,563.    Elapsed: 0:06:09.
#   Batch 30,700  of  1,563.    Elapsed: 0:06:10.
#   Batch 30,800  of  1,563.    Elapsed: 0:06:11.
#   Batch 30,900  of  1,563.    Elapsed: 0:06:12.
#   Batch 31,000  of  1,563.    Elapsed: 0:06:14.
#   Batch 31,100  of  1,563.    Elapsed: 0:06:15.
#   Batch 31,200  of  1,563.    Elapsed: 0:06:16.
#   Batch 31,300  of  1,563.    Elapsed: 0:06:17.
#   Batch 31,400  of  1,563.    Elapsed: 0:06:18.
#   Batch 31,500  of  1,563.    Elapsed: 0:06:20.
#   Batch 31,600  of  1,563.    Elapsed: 0:06:21.
#   Batch 31,700  of  1,563.    Elapsed: 0:06:22.
#   Batch 31,800  of  1,563.    Elapsed: 0:06:23.
#   Batch 31,900  of  1,563.    Elapsed: 0:06:24.
#   Batch 32,000  of  1,563.    Elapsed: 0:06:25.
#   Batch 32,100  of  1,563.    Elapsed: 0:06:27.
#   Batch 32,200  of  1,563.    Elapsed: 0:06:28.
#   Batch 32,300  of  1,563.    Elapsed: 0:06:29.
#   Batch 32,400  of  1,563.    Elapsed: 0:06:30.
#   Batch 32,500  of  1,563.    Elapsed: 0:06:31.
#   Batch 32,600  of  1,563.    Elapsed: 0:06:32.
#   Batch 32,700  of  1,563.    Elapsed: 0:06:34.
#   Batch 32,800  of  1,563.    Elapsed: 0:06:35.
#   Batch 32,900  of  1,563.    Elapsed: 0:06:36.
#   Batch 33,000  of  1,563.    Elapsed: 0:06:37.
#   Batch 33,100  of  1,563.    Elapsed: 0:06:38.
#   Batch 33,200  of  1,563.    Elapsed: 0:06:40.
#   Batch 33,300  of  1,563.    Elapsed: 0:06:41.
#   Batch 33,400  of  1,563.    Elapsed: 0:06:42.
#   Batch 33,500  of  1,563.    Elapsed: 0:06:43.
#   Batch 33,600  of  1,563.    Elapsed: 0:06:44.
#   Batch 33,700  of  1,563.    Elapsed: 0:06:46.
#   Batch 33,800  of  1,563.    Elapsed: 0:06:47.
#   Batch 33,900  of  1,563.    Elapsed: 0:06:48.
#   Batch 34,000  of  1,563.    Elapsed: 0:06:49.
#   Batch 34,100  of  1,563.    Elapsed: 0:06:50.
#   Batch 34,200  of  1,563.    Elapsed: 0:06:52.
#   Batch 34,300  of  1,563.    Elapsed: 0:06:53.
#   Batch 34,400  of  1,563.    Elapsed: 0:06:54.
#   Batch 34,500  of  1,563.    Elapsed: 0:06:55.
#   Batch 34,600  of  1,563.    Elapsed: 0:06:56.
#   Batch 34,700  of  1,563.    Elapsed: 0:06:58.
#   Batch 34,800  of  1,563.    Elapsed: 0:06:59.
#   Batch 34,900  of  1,563.    Elapsed: 0:07:00.
#   Batch 35,000  of  1,563.    Elapsed: 0:07:01.
#   Batch 35,100  of  1,563.    Elapsed: 0:07:02.
#   Batch 35,200  of  1,563.    Elapsed: 0:07:03.
#   Batch 35,300  of  1,563.    Elapsed: 0:07:05.
#   Batch 35,400  of  1,563.    Elapsed: 0:07:06.
#   Batch 35,500  of  1,563.    Elapsed: 0:07:07.
#   Batch 35,600  of  1,563.    Elapsed: 0:07:08.
#   Batch 35,700  of  1,563.    Elapsed: 0:07:09.
#   Batch 35,800  of  1,563.    Elapsed: 0:07:11.
#   Batch 35,900  of  1,563.    Elapsed: 0:07:12.
#   Batch 36,000  of  1,563.    Elapsed: 0:07:13.
#   Batch 36,100  of  1,563.    Elapsed: 0:07:14.
#   Batch 36,200  of  1,563.    Elapsed: 0:07:16.
#   Batch 36,300  of  1,563.    Elapsed: 0:07:17.
#   Batch 36,400  of  1,563.    Elapsed: 0:07:18.
#   Batch 36,500  of  1,563.    Elapsed: 0:07:19.
#   Batch 36,600  of  1,563.    Elapsed: 0:07:20.
#   Batch 36,700  of  1,563.    Elapsed: 0:07:22.
#   Batch 36,800  of  1,563.    Elapsed: 0:07:23.
#   Batch 36,900  of  1,563.    Elapsed: 0:07:24.
#   Batch 37,000  of  1,563.    Elapsed: 0:07:25.
#   Batch 37,100  of  1,563.    Elapsed: 0:07:26.
#   Batch 37,200  of  1,563.    Elapsed: 0:07:28.
#   Batch 37,300  of  1,563.    Elapsed: 0:07:29.
#   Batch 37,400  of  1,563.    Elapsed: 0:07:30.
#   Batch 37,500  of  1,563.    Elapsed: 0:07:31.
#   Batch 37,600  of  1,563.    Elapsed: 0:07:32.
#   Batch 37,700  of  1,563.    Elapsed: 0:07:34.
#   Batch 37,800  of  1,563.    Elapsed: 0:07:35.
#   Batch 37,900  of  1,563.    Elapsed: 0:07:36.
#   Batch 38,000  of  1,563.    Elapsed: 0:07:37.
#   Batch 38,100  of  1,563.    Elapsed: 0:07:39.
#   Batch 38,200  of  1,563.    Elapsed: 0:07:40.
#   Batch 38,300  of  1,563.    Elapsed: 0:07:41.
#   Batch 38,400  of  1,563.    Elapsed: 0:07:42.
#   Batch 38,500  of  1,563.    Elapsed: 0:07:43.
#   Batch 38,600  of  1,563.    Elapsed: 0:07:45.
#   Batch 38,700  of  1,563.    Elapsed: 0:07:46.
#   Batch 38,800  of  1,563.    Elapsed: 0:07:47.
#   Batch 38,900  of  1,563.    Elapsed: 0:07:48.
#   Batch 39,000  of  1,563.    Elapsed: 0:07:50.
#   Batch 39,100  of  1,563.    Elapsed: 0:07:51.
#   Batch 39,200  of  1,563.    Elapsed: 0:07:52.
#   Batch 39,300  of  1,563.    Elapsed: 0:07:53.
#   Batch 39,400  of  1,563.    Elapsed: 0:07:54.
#   Batch 39,500  of  1,563.    Elapsed: 0:07:56.
#   Batch 39,600  of  1,563.    Elapsed: 0:07:57.
#   Batch 39,700  of  1,563.    Elapsed: 0:07:58.
#   Batch 39,800  of  1,563.    Elapsed: 0:07:59.
#   Batch 39,900  of  1,563.    Elapsed: 0:08:00.
#   Batch 40,000  of  1,563.    Elapsed: 0:08:02.
#   Batch 40,100  of  1,563.    Elapsed: 0:08:03.
#   Batch 40,200  of  1,563.    Elapsed: 0:08:04.
#   Batch 40,300  of  1,563.    Elapsed: 0:08:05.
#   Batch 40,400  of  1,563.    Elapsed: 0:08:06.
#   Batch 40,500  of  1,563.    Elapsed: 0:08:08.
#   Batch 40,600  of  1,563.    Elapsed: 0:08:09.
#   Batch 40,700  of  1,563.    Elapsed: 0:08:10.
#   Batch 40,800  of  1,563.    Elapsed: 0:08:11.
#   Batch 40,900  of  1,563.    Elapsed: 0:08:13.
#   Batch 41,000  of  1,563.    Elapsed: 0:08:14.
#   Batch 41,100  of  1,563.    Elapsed: 0:08:15.
#   Batch 41,200  of  1,563.    Elapsed: 0:08:16.
#   Batch 41,300  of  1,563.    Elapsed: 0:08:18.
#   Batch 41,400  of  1,563.    Elapsed: 0:08:19.
#   Batch 41,500  of  1,563.    Elapsed: 0:08:20.
#   Batch 41,600  of  1,563.    Elapsed: 0:08:21.
#   Batch 41,700  of  1,563.    Elapsed: 0:08:22.
#   Batch 41,800  of  1,563.    Elapsed: 0:08:24.
#   Batch 41,900  of  1,563.    Elapsed: 0:08:25.
#   Batch 42,000  of  1,563.    Elapsed: 0:08:26.
#   Batch 42,100  of  1,563.    Elapsed: 0:08:27.
#   Batch 42,200  of  1,563.    Elapsed: 0:08:28.
#   Batch 42,300  of  1,563.    Elapsed: 0:08:30.
#   Batch 42,400  of  1,563.    Elapsed: 0:08:31.
#   Batch 42,500  of  1,563.    Elapsed: 0:08:32.
#   Batch 42,600  of  1,563.    Elapsed: 0:08:33.
#   Batch 42,700  of  1,563.    Elapsed: 0:08:34.
#   Batch 42,800  of  1,563.    Elapsed: 0:08:35.
#   Batch 42,900  of  1,563.    Elapsed: 0:08:37.
#   Batch 43,000  of  1,563.    Elapsed: 0:08:38.
#   Batch 43,100  of  1,563.    Elapsed: 0:08:39.
#   Batch 43,200  of  1,563.    Elapsed: 0:08:40.
#   Batch 43,300  of  1,563.    Elapsed: 0:08:42.
#   Batch 43,400  of  1,563.    Elapsed: 0:08:43.
#   Batch 43,500  of  1,563.    Elapsed: 0:08:44.
#   Batch 43,600  of  1,563.    Elapsed: 0:08:45.
#   Batch 43,700  of  1,563.    Elapsed: 0:08:46.
#   Batch 43,800  of  1,563.    Elapsed: 0:08:48.
#   Batch 43,900  of  1,563.    Elapsed: 0:08:49.
#   Batch 44,000  of  1,563.    Elapsed: 0:08:50.
#   Batch 44,100  of  1,563.    Elapsed: 0:08:51.
#   Batch 44,200  of  1,563.    Elapsed: 0:08:52.
#   Batch 44,300  of  1,563.    Elapsed: 0:08:53.
#   Batch 44,400  of  1,563.    Elapsed: 0:08:55.
#   Batch 44,500  of  1,563.    Elapsed: 0:08:56.
#   Batch 44,600  of  1,563.    Elapsed: 0:08:57.
#   Batch 44,700  of  1,563.    Elapsed: 0:08:58.
#   Batch 44,800  of  1,563.    Elapsed: 0:09:00.
#   Batch 44,900  of  1,563.    Elapsed: 0:09:01.
#   Batch 45,000  of  1,563.    Elapsed: 0:09:02.
#   Batch 45,100  of  1,563.    Elapsed: 0:09:03.
#   Batch 45,200  of  1,563.    Elapsed: 0:09:04.
#   Batch 45,300  of  1,563.    Elapsed: 0:09:06.
#   Batch 45,400  of  1,563.    Elapsed: 0:09:07.
#   Batch 45,500  of  1,563.    Elapsed: 0:09:08.
#   Batch 45,600  of  1,563.    Elapsed: 0:09:09.
#   Batch 45,700  of  1,563.    Elapsed: 0:09:10.
#   Batch 45,800  of  1,563.    Elapsed: 0:09:11.
#   Batch 45,900  of  1,563.    Elapsed: 0:09:13.
#   Batch 46,000  of  1,563.    Elapsed: 0:09:14.
#   Batch 46,100  of  1,563.    Elapsed: 0:09:15.
#   Batch 46,200  of  1,563.    Elapsed: 0:09:16.
#   Batch 46,300  of  1,563.    Elapsed: 0:09:17.
#   Batch 46,400  of  1,563.    Elapsed: 0:09:19.
#   Batch 46,500  of  1,563.    Elapsed: 0:09:20.
#   Batch 46,600  of  1,563.    Elapsed: 0:09:21.
#   Batch 46,700  of  1,563.    Elapsed: 0:09:22.
#   Batch 46,800  of  1,563.    Elapsed: 0:09:23.
#   Batch 46,900  of  1,563.    Elapsed: 0:09:24.
#   Batch 47,000  of  1,563.    Elapsed: 0:09:25.
#   Batch 47,100  of  1,563.    Elapsed: 0:09:27.
#   Batch 47,200  of  1,563.    Elapsed: 0:09:28.
#   Batch 47,300  of  1,563.    Elapsed: 0:09:29.
#   Batch 47,400  of  1,563.    Elapsed: 0:09:31.
#   Batch 47,500  of  1,563.    Elapsed: 0:09:32.
#   Batch 47,600  of  1,563.    Elapsed: 0:09:33.
#   Batch 47,700  of  1,563.    Elapsed: 0:09:34.
#   Batch 47,800  of  1,563.    Elapsed: 0:09:35.
#   Batch 47,900  of  1,563.    Elapsed: 0:09:37.
#   Batch 48,000  of  1,563.    Elapsed: 0:09:38.
#   Batch 48,100  of  1,563.    Elapsed: 0:09:39.
#   Batch 48,200  of  1,563.    Elapsed: 0:09:40.
#   Batch 48,300  of  1,563.    Elapsed: 0:09:42.
#   Batch 48,400  of  1,563.    Elapsed: 0:09:43.
#   Batch 48,500  of  1,563.    Elapsed: 0:09:44.
#   Batch 48,600  of  1,563.    Elapsed: 0:09:45.
#   Batch 48,700  of  1,563.    Elapsed: 0:09:46.
#   Batch 48,800  of  1,563.    Elapsed: 0:09:48.
#   Batch 48,900  of  1,563.    Elapsed: 0:09:49.
#   Batch 49,000  of  1,563.    Elapsed: 0:09:50.
#   Batch 49,100  of  1,563.    Elapsed: 0:09:51.
#   Batch 49,200  of  1,563.    Elapsed: 0:09:53.
#   Batch 49,300  of  1,563.    Elapsed: 0:09:54.
#   Batch 49,400  of  1,563.    Elapsed: 0:09:55.
#   Batch 49,500  of  1,563.    Elapsed: 0:09:56.
#   Batch 49,600  of  1,563.    Elapsed: 0:09:58.
#   Batch 49,700  of  1,563.    Elapsed: 0:09:59.
#   Batch 49,800  of  1,563.    Elapsed: 0:10:00.
#   Batch 49,900  of  1,563.    Elapsed: 0:10:01.
#
# Test took: 0:10:02

# %%
test_csv = test_result.to_csv('test.csv')

# %%
from google.colab import files

files.download('test.csv')

# %% [markdown]
# 코드 참고 1. https://blog.naver.com/horajjan/221739630055
#
# 코드 참고 2. https://github.com/jiwonny
